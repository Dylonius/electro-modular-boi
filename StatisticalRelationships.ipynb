# %% [markdown]
# <a href="https://colab.research.google.com/github/Dylonius/electro-modular-boi/blob/main/StatisticalRelationships.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
a = [1,2,3,4,5,6,7,8]
b = [5,2,11,4,7,11,7,12]
c = ['yes','no','yes','no','yes','no','yes','no']

# %%
sns.relplot(x= a, y= b, hue= c)

# %%
sns.relplot(x=a, y=b, kind="line")
