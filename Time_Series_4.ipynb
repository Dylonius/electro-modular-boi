# %% [markdown]
# <a href="https://colab.research.google.com/github/Dylonius/electro-modular-boi/blob/main/Time_Series_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload

# %%
data = pd.read_csv("Course+DataSet.csv",index_col = "DATE",parse_dates = True)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose = seasonal_decompose(data["Price"],model = "additive")

# %%
decompose.plot()
plt.show()
