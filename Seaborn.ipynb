# %% [markdown]
# <a href="https://colab.research.google.com/github/Dylonius/electro-modular-boi/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries
import seaborn as sns

# %%
a = [1,2,3,4,5,6,7,8]
b = [5,2,11,4,7,11,7,12]
c = ['yes','no','yes','no','yes','no','yes','no']

# %%
sns.displot(b)

# %%
sns.displot(b,bins = 2)

# %%
sns.displot(b,binwidth=3)

# %%
sns.displot(x=b, hue = c)

# %%
sns.displot(x=b, col = c)

# %%
sns.displot(x=b, y=a)

# %%
sns.displot(x=b, y=a,hue=c)

# %%
sns.jointplot(x=b, y=a)
