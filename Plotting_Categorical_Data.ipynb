# %% [markdown]
# <a href="https://colab.research.google.com/github/Dylonius/electro-modular-boi/blob/main/Plotting_Categorical_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries
import pandas as pd
import seaborn as sns

# %%
a = [1,2,3,4,5,6,7,8]
b = [5,2,11,4,7,11,7,12]
c = ['yes','no','yes','no','yes','no','yes','no']
data = {"a":a,"b":b,"c":c}
df= pd.DataFrame(data)

# %%
#categorical as x
sns.catplot(data = df , x = c, y = a)

# %%
sns.catplot(x=c, y=a, kind="box",data = df)

# %%
sns.catplot(x=a, y=c,
            kind="violin", data=df)

# %%
sns.catplot(x=c, y=a, kind="bar", data=df)

# %%
sns.catplot(x=c, y=a, kind="point", data=df)
