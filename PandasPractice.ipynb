# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f4adb423-241c-4637-a9e3-051149099a36" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f4adb423-241c-4637-a9e3-051149099a36">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Stores.csv')
df.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %%
df.columns
# Out:
# Index(['Store ID ', 'Store_Area', 'Items_Available', 'Daily_Customer_Count',
#        'Store_Sales'],
#       dtype='object')

# %%
df.shape
# Out:
# (896, 5)

# %%
# Finding the index with max and min values
df["Store_Sales"].idxmax()
# Out:
# 649

# %%
df.iloc[648]
# Out:
# Store ID                  649
# Store_Area               1514
# Items_Available          1794
# Daily_Customer_Count     1400
# Store_Sales             54820
# Name: 648, dtype: int64

# %%
df["Store_Sales"].idxmin()
# Out:
# 31

# %%
df.iloc[30]
# Out:
# Store ID                   31
# Store_Area               1439
# Items_Available          1746
# Daily_Customer_Count      990
# Store_Sales             80140
# Name: 30, dtype: int64

# %%
df = df.drop("Store ID ", axis ="columns")

# %%
df.head()
# Out:
#    Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0        1659             1961                   530        66490
# 1        1461             1752                   210        39820
# 2        1340             1609                   720        54010
# 3        1451             1748                   620        53730
# 4        1770             2111                   450        46620

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Store_Area              0
# Items_Available         0
# Daily_Customer_Count    0
# Store_Sales             0
# dtype: int64

# %%
# if there is na or duplicated values
# for na            df.dropna(inplace=True) can be applied
# for duplicates    df.dropduplicates(inplace=True) can be applied

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Store_Area            896 non-null    int64
#  1   Items_Available       896 non-null    int64
#  2   Daily_Customer_Count  896 non-null    int64
#  3   Store_Sales           896 non-null    int64
# dtypes: int64(4)
# memory usage: 28.1 KB

# %%
df.describe()
# Out:
#         Store_Area  Items_Available  Daily_Customer_Count    Store_Sales
# count   896.000000       896.000000            896.000000     896.000000
# mean   1485.409598      1782.035714            786.350446   59351.305804
# std     250.237011       299.872053            265.389281   17190.741895
# min     775.000000       932.000000             10.000000   14920.000000
# 25%    1316.750000      1575.500000            600.000000   46530.000000
# 50%    1477.000000      1773.500000            780.000000   58605.000000
# 75%    1653.500000      1982.750000            970.000000   71872.500000
# max    2229.000000      2667.000000           1560.000000  116320.000000

# %%
df.corr()["Store_Sales"].sort_values()
# Out:
# Daily_Customer_Count    0.008629
# Store_Area              0.097474
# Items_Available         0.098849
# Store_Sales             1.000000
# Name: Store_Sales, dtype: float64

# %%
df.sort_values(by="Store_Sales")
# Out:
#      Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 31         1250             1508                   990        14920
# 852        1477             1790                   880        16370
# 775        1537             1877                   660        17670
# 593        1624             1946                   870        20270
# 352        1397             1686                   850        21300
# ..          ...              ...                   ...          ...
# 758        1486             1758                   820       101820
# 408        1303             1587                  1310       102310
# 432        1365             1638                   680       102920
# 868        1775             2104                   980       105150
# 649        1989             2414                   860       116320
#
# [896 rows x 4 columns]
