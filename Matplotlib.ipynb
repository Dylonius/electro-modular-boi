# %% [markdown]
# <a href="https://colab.research.google.com/github/Dylonius/electro-modular-boi/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
a = [1,2,3,4,5,6,7,8]
b = [5,2,11,4,7,11,7,12]
c = ['yes','no','yes','no','yes','no','yes','no']

# %%
#plot types

# %%
plt.plot(a,b)

# %%
plt.scatter(a,b)

# %%
plt.bar(a,b)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.stem(a,b)
# Out:
# <StemContainer object of 3 artists>

# %%
plt.step(a,b)

# %%
#parameters

# %%
plt.plot(a,b)

# %%
plt.plot(a,b,color = "green")

# %%
plt.plot(a,b,linestyle = "dashed")

# %%
plt.plot(a,b,linestyle = "dotted")

# %%
plt.plot(a,b)
plt.xlabel("your x label")
plt.ylabel("your y label")
# Out:
# Text(0, 0.5, 'your y label')

# %%
plt.plot(a,b)
plt.xlabel("your x label")
plt.ylabel("your y label")
plt.title("your title")
# Out:
# Text(0.5, 1.0, 'your title')
