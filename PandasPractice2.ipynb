# %% [markdown]
# <a href="https://colab.research.google.com/github/Dylonius/electro-modular-boi/blob/main/PandasPractice2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload

# %%
data = pd.read_csv("Course+DataSet.csv",index_col = "DATE",parse_dates = False)

# %%
data.head()
# Out:
#               Price
# DATE
# 01-01-1985  72.5052
# 02-01-1985  70.6720
# 03-01-1985  62.4502
# 04-01-1985  57.4714
# 05-01-1985  55.3151

# %%
data.tail()
# Out:
#                Price
# DATE
# 09-01-2017   98.6154
# 10-01-2017   93.6137
# 11-01-2017   97.3359
# 12-01-2017  114.7212
# 01-01-2018  129.4048

# %%
data.shape
# Out:
# (397, 1)

# %%
data.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='DATE'>

# %%
start_date = "01-01-2000"
end_date = "01-01-2005"
timelim = (data.index >= start_date) & (data.index <= end_date)
datanew = data.loc[timelim]

# %%
datanew.head()
# Out:
#                Price
# DATE
# 01-01-2000  102.2301
# 01-01-2001  109.1081
# 01-01-2002  102.9955
# 01-01-2003  110.1807
# 01-01-2004  113.7226

# %%
datanew.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='DATE'>

# %%
  dataquarterly = data.rolling(window=3).mean()

# %%
dataquarterly.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='DATE'>

# %%
datayearly = data.rolling(window=12).mean()
datayearly.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='DATE'>

# %%
from pandas.plotting import lag_plot
lag_plot(data["Price"])
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>
