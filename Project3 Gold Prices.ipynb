# %% [markdown]
# <a href="https://colab.research.google.com/github/Dylonius/electro-modular-boi/blob/main/Project3%20Gold%20Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("data.csv",index_col="date",parse_dates=True)

# %%
data.head()
# Out:
#             price
# date
# 1950-01-01  34.73
# 1950-02-01  34.73
# 1950-03-01  34.73
# 1950-04-01  34.73
# 1950-05-01  34.73

# %%
data.tail()
# Out:
#                price
# date
# 2017-10-01  1280.677
# 2017-11-01  1283.189
# 2017-12-01  1265.674
# 2018-01-01  1332.809
# 2018-02-01  1333.775

# %%
import matplotlib.pyplot as plt
data.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='date'>

# %%
start_date = "2009-01-01"
end_date = "2018-01-01"
mask = (data.index >= start_date)&(data.index <= end_date)
data = data.loc[mask]

# %%
data.index.freq = "MS"
data.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='date'>

# %%
datayearly = data.rolling(window=12).mean()

# %%
datayearly.plot(title="Yearly Avg Gold Prices")
# Out:
# <Axes: title={'center': 'Yearly Avg Gold Prices'}, xlabel='date'>
